# %%
# !pip install -q ultralytics roboflow

from ultralytics import YOLO
from roboflow import Roboflow
import os, shutil

MY_API_KEY = "nUQk1v6QdnBLLOpnZWgf"
MY_WORKSPACE = "peace-3krec"
MY_PROJECT = "self-driving-car-xuita-lyasw"
MY_VERSION = 1

# Ortam temizliği
for p in ["/content/datasets", "/content/runs"]:
    if os.path.exists(p):
        shutil.rmtree(p)

print("📥 Dataset indiriliyor...")

rf = Roboflow(api_key=MY_API_KEY)
project = rf.workspace(MY_WORKSPACE).project(MY_PROJECT)
dataset = project.version(MY_VERSION).download("yolov8")

print("🚀 Eğitim başlıyor...")

model = YOLO("yolov8s.pt")  # 👈 daha doğru seçim

model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    patience=10,
    name="traffic_sign_final",
    plots=True
)

print("✅ Eğitim bitti")
